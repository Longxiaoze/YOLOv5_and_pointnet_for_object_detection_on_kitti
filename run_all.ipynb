# %% [markdown]
# # 自动驾驶课设

# %% [markdown]
# ## yolov5

# %% [markdown]
# 代码见[kaggle平台（点击进入）](https://www.kaggle.com/longxiaoze/yolov5-in-kitti-detection/)

# %%
# %cd 01-YOLOv5/
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu102 (GeForce RTX 2080 Ti)

# %%
# %ls
# Out:
# data/        LICENSE            train.py        yolov5l6.pt  yolov5s.pt
# detect.py    models/            tutorial.ipynb  yolov5l.pt   yolov5x6.pt
# Dockerfile   README.md*         utils/          yolov5m6.pt  yolov5x.pt
# hubconf.py   requirements.txt*  videos/         yolov5m.pt
# __init__.py  test.py            weights/        yolov5s6.pt

# %%
# !python detect.py --weights yolov5x.pt --img 640 --conf 0.25 --source videos/
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='videos/', update=False, view_img=False, weights=['yolov5x.pt'])
# YOLOv5 🚀 2021-5-28 torch 1.8.1+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019.4375MB)
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients
# video 1/3 (1/409) /data-input/zidongjiashi/01-YOLOv5/yolov5/videos/1.mp4: 384x640 1 person, 7 cars, 1 bus, 1 truck, 1 traffic light, Done. (0.021s)
# video 1/3 (2/409) /data-input/zidongjiashi/01-YOLOv5/yolov5/videos/1.mp4: 384x640 1 person, 5 cars, 1 bus, 1 traffic light, Done. (0.025s)
# video 1/3 (3/409) /data-input/zidongjiashi/01-YOLOv5/yolov5/videos/1.mp4: 384x640 1 person, 5 cars, 1 bus, 1 traffic light, Done. (0.019s)
# ...

# %%
# %cd ../../
# %ls

# %% [markdown]
# ## pointnet

# %%
# %cd 02-pointnet_object_detection/
# %ls
# Out:
# /data-input/zidongjiashi/02-pointnet_object_detection
# data_augmentation.py*      object_detect.py*   README.md*
# generate_training_set.py*  pictures/           train_pointnet.ipynb*
# logs/                      pointnet_model.h5*

# %%
# !python object_detect.py --input_dir data-input/KITTI_3D_Object_Detection_2017/ --debug False

# %%
# %cd ../
# %ls
# Out:
# /data-input/zidongjiashi
# 01-YOLOv5/  02-pointnet_object_detection/  03-可视化/  run_all.ipynb

# %% [markdown]
# ## 可视化部分

# %% [markdown]
# 此部分都是集成性质的代码，运行时无需全部的kitti数据集，我已经在每一个文件夹下存放一帧对应的数据，可以无障碍分别运行。
#
# 运行时请参看readme文件或者ipynb文件
